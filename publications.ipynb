# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Here we read in data downloaded as CSV form from ``cdli_db``.

# %%
pubs = pd.read_csv("publications.csv")
artifs_pubs = pd.read_csv("artifacts_publications.csv")
abbrev = pd.read_csv("abbreviations.csv")
# Out:
# d:\Programming\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3229: DtypeWarning: Columns (2,3,5,7,8,11,12,17,19,20,21,22,23,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# d:\Programming\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3229: DtypeWarning: Columns (3,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Step 1: Identify subsets of publications that may be curated.

# %% [markdown]
# A lot of fields have the form like "ATU 3, pl. 036, W 12139", where "ATU 3" is an assyriological abbreviation and what goes
# after the comma is exact_reference.
#
# We can pull out all the publications that has such "assyriological abbreviation".
#
# So first we split the designation column by a comma and take what goes before the first comma. Name it "designation_first".
# Then we pick all rows where there is a numeric character in "designation_first".

# %%
des_first = pubs["designation"].fillna("").str.split(",", n = 1, expand = True)[0]
pubs["designation_first"] = des_first
mergeable = pubs[pubs["designation_first"].str.match(".*\d.*")]

# %% [markdown]
# We assume these rows are formatted as "abbrev name + number", so extract the abbrev name.
#
# Then we check if these names exist in the abbreviations table
#
# Hopefully this can isolate some publications which may be merged.

# %%
mergeable_abbrevs = mergeable["designation_first"].str.split(" ", n = 1, expand = True)[0]
mergeable.loc[:, "designation_abbrev"] = mergeable_abbrevs

all_abbrevs = abbrev["abbreviation"].str.replace("\s\(aka.*\)", "").str.strip()
mergeable = mergeable[mergeable["designation_abbrev"].isin(all_abbrevs)]
mergeable.head()
# Out:
# d:\Programming\Anaconda\lib\site-packages\pandas\core\indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# d:\Programming\Anaconda\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#       id              designation    bibtexkey  year  entry_type_id address  \
# 467  468                 CUSAS 35  Bartash2017  2017            NaN     NaN
# 468  472                    ATU 3  Englund1993  1993            NaN     NaN
# 469  483  ATU 3, pl. 036, W 12139     1993-483  1993            NaN     NaN
# 470  487  ATU 3, pl. 080, W 13948     1993-487  1993            NaN     NaN
# 471  488  ATU 3, pl. 082, W 13982     1993-488  1993            NaN     NaN
#
#      annote                                         book_title chapter  \
# 467     NaN                                                NaN     NaN
# 468     NaN  Die lexikalischen Listen der Archaischen Texte...     NaN
# 469     NaN                                                NaN     NaN
# 470     NaN                                                NaN     NaN
# 471     NaN                                                NaN     NaN
#
#      crossref  ...  school                                              title  \
# 467       NaN  ...     NaN  Sumerian Administrative and Legal Documents ca...
# 468       NaN  ...     NaN                                                NaN
# 469       NaN  ...     NaN                                                NaN
# 470       NaN  ...     NaN                                                NaN
# 471       NaN  ...     NaN                                                NaN
#
#     volume  publication_history  series  oclc  accepted_by accepted  \
# 467    NaN                  NaN     NaN   NaN          820        1
# 468    NaN                  NaN     NaN   NaN          820        1
# 469    NaN                  NaN     NaN   NaN          820        1
# 470    NaN                  NaN     NaN   NaN          820        1
# 471    NaN                  NaN     NaN   NaN          820        1
#
#      designation_first designation_abbrev
# 467           CUSAS 35              CUSAS
# 468              ATU 3                ATU
# 469              ATU 3                ATU
# 470              ATU 3                ATU
# 471              ATU 3                ATU
#
# [5 rows x 31 columns]

# %% [markdown]
# We can perform another round of filtering by removing designations with 1 entry. There's no point for merging them at this point

# %%
def filter_func(df):
    return df.shape[0] > 1

mergeable = mergeable.groupby("designation_first").filter(filter_func)
mergeable
# Out:
#              id              designation    bibtexkey  year  entry_type_id  \
# 467         468                 CUSAS 35  Bartash2017  2017            NaN
# 468         472                    ATU 3  Englund1993  1993            NaN
# 469         483  ATU 3, pl. 036, W 12139     1993-483  1993            NaN
# 470         487  ATU 3, pl. 080, W 13948     1993-487  1993            NaN
# 471         488  ATU 3, pl. 082, W 13982     1993-488  1993            NaN
# ...         ...                      ...          ...   ...            ...
# 418179  1000896               RA 98, 148      1000896   NaN            NaN
# 418180  1000898               RA 98, 148      1000898   NaN            NaN
# 418181  1000901               RA 97, 171      1000901   NaN            NaN
# 418182  1013101               RA 76, 011      1013101   NaN            NaN
# 418183  1013102               RA 76, 011      1013102   NaN            NaN
#
#        address  annote                                         book_title  \
# 467        NaN     NaN                                                NaN
# 468        NaN     NaN  Die lexikalischen Listen der Archaischen Texte...
# 469        NaN     NaN                                                NaN
# 470        NaN     NaN                                                NaN
# 471        NaN     NaN                                                NaN
# ...        ...     ...                                                ...
# 418179     NaN     NaN                                                NaN
# 418180     NaN     NaN                                                NaN
# 418181     NaN     NaN                                                NaN
# 418182     NaN     NaN                                                NaN
# 418183     NaN     NaN                                                NaN
#
#        chapter  crossref  ...  school  \
# 467        NaN       NaN  ...     NaN
# 468        NaN       NaN  ...     NaN
# 469        NaN       NaN  ...     NaN
# 470        NaN       NaN  ...     NaN
# 471        NaN       NaN  ...     NaN
# ...        ...       ...  ...     ...
# 418179     NaN       NaN  ...     NaN
# 418180     NaN       NaN  ...     NaN
# 418181     NaN       NaN  ...     NaN
# 418182     NaN       NaN  ...     NaN
# 418183     NaN       NaN  ...     NaN
#
#                                                     title volume  \
# 467     Sumerian Administrative and Legal Documents ca...    NaN
# 468                                                   NaN    NaN
# 469                                                   NaN    NaN
# 470                                                   NaN    NaN
# 471                                                   NaN    NaN
# ...                                                   ...    ...
# 418179                                                NaN    NaN
# 418180                                                NaN    NaN
# 418181                                                NaN    NaN
# 418182                                                NaN    NaN
# 418183                                                NaN    NaN
#
#         publication_history  series  oclc  accepted_by accepted  \
# 467                     NaN     NaN   NaN          820        1
# 468                     NaN     NaN   NaN          820        1
# 469                     NaN     NaN   NaN          820        1
# 470                     NaN     NaN   NaN          820        1
# 471                     NaN     NaN   NaN          820        1
# ...                     ...     ...   ...          ...      ...
# 418179                  NaN     NaN   NaN          820        1
# 418180                  NaN     NaN   NaN          820        1
# 418181                  NaN     NaN   NaN          820        1
# 418182                  NaN     NaN   NaN          820        1
# 418183                  NaN     NaN   NaN          820        1
#
#         designation_first designation_abbrev
# 467              CUSAS 35              CUSAS
# 468                 ATU 3                ATU
# 469                 ATU 3                ATU
# 470                 ATU 3                ATU
# 471                 ATU 3                ATU
# ...                   ...                ...
# 418179              RA 98                 RA
# 418180              RA 98                 RA
# 418181              RA 97                 RA
# 418182              RA 76                 RA
# 418183              RA 76                 RA
#
# [188447 rows x 31 columns]

# %% [markdown]
# # Step 2: Try to merge some of them.
#
# Here we try those with "ATU 3"

# %%
# Find all entries with that abbreviation name
abbrev_name = "CUSAS 35"
subset = mergeable[mergeable["designation_first"] == abbrev_name]

# Split into entries to be replaced (to_replace), and what they will be changed to (replace_with)
to_replace, replace_with = subset[subset["book_title"].isna() & subset["title"].isna()], subset[~subset["book_title"].isna() | ~subset["title"].isna()]
replace_with.head()
# Out:
#       id designation    bibtexkey  year  entry_type_id address  annote  \
# 467  468    CUSAS 35  Bartash2017  2017            NaN     NaN     NaN
#
#     book_title chapter  crossref  ...  school  \
# 467        NaN     NaN       NaN  ...     NaN
#
#                                                  title volume  \
# 467  Sumerian Administrative and Legal Documents ca...    NaN
#
#      publication_history  series  oclc  accepted_by accepted  \
# 467                  NaN     NaN   NaN          820        1
#
#      designation_first designation_abbrev
# 467           CUSAS 35              CUSAS
#
# [1 rows x 31 columns]

# %%
# Treat what goes after the first comma in designation as exact_referece
exact_reference = to_replace["designation"].str.split(",", 1, True)[1]
exact_reference.head()
# Out:
# 75942     471
# 75943     472
# 75945     477
# 81944     474
# 81955     469
# Name: 1, dtype: object

# %%
# Fetch the id of the publications to be replaced
ids_to_replace = to_replace["id"]
ids_to_replace.head()

# Fetch the id these publications will be changed to
replace_id = replace_with["id"].iloc[0]

# %%
ids_to_replace
# Out:
# 75942      77374
# 75943      77375
# 75945      77391
# 81944      83445
# 81955      83456
#            ...
# 202653    221149
# 202655    221151
# 202656    221152
# 203609    222134
# 203610    222135
# Name: id, Length: 521, dtype: int64

# %%
# Update the artifacts_publications table
if not any(artifs_pubs["publication_id"].isin(ids_to_replace)):
    print("No corresponding entries in artifacts_publications.")
else:
    artifs_pubs.loc[artifs_pubs["publication_id"].isin(ids_to_replace), "exact_reference"] = exact_reference.to_numpy()
    artifs_pubs.loc[artifs_pubs["publication_id"].isin(ids_to_replace), "publication_id"] = replace_id
    artifs_pubs.head()
# Out:
# No corresponding entries in artifacts_publications.

# %%
# Update the mergeable table
mergeable.drop(mergeable.index[mergeable["id"].isin(ids_to_replace)])
# Out:
#              id              designation    bibtexkey  year  entry_type_id  \
# 467         468                 CUSAS 35  Bartash2017  2017            NaN
# 468         472                    ATU 3  Englund1993  1993            NaN
# 469         483  ATU 3, pl. 036, W 12139     1993-483  1993            NaN
# 470         487  ATU 3, pl. 080, W 13948     1993-487  1993            NaN
# 471         488  ATU 3, pl. 082, W 13982     1993-488  1993            NaN
# ...         ...                      ...          ...   ...            ...
# 418179  1000896               RA 98, 148      1000896   NaN            NaN
# 418180  1000898               RA 98, 148      1000898   NaN            NaN
# 418181  1000901               RA 97, 171      1000901   NaN            NaN
# 418182  1013101               RA 76, 011      1013101   NaN            NaN
# 418183  1013102               RA 76, 011      1013102   NaN            NaN
#
#        address  annote                                         book_title  \
# 467        NaN     NaN                                                NaN
# 468        NaN     NaN  Die lexikalischen Listen der Archaischen Texte...
# 469        NaN     NaN                                                NaN
# 470        NaN     NaN                                                NaN
# 471        NaN     NaN                                                NaN
# ...        ...     ...                                                ...
# 418179     NaN     NaN                                                NaN
# 418180     NaN     NaN                                                NaN
# 418181     NaN     NaN                                                NaN
# 418182     NaN     NaN                                                NaN
# 418183     NaN     NaN                                                NaN
#
#        chapter  crossref  ...  school  \
# 467        NaN       NaN  ...     NaN
# 468        NaN       NaN  ...     NaN
# 469        NaN       NaN  ...     NaN
# 470        NaN       NaN  ...     NaN
# 471        NaN       NaN  ...     NaN
# ...        ...       ...  ...     ...
# 418179     NaN       NaN  ...     NaN
# 418180     NaN       NaN  ...     NaN
# 418181     NaN       NaN  ...     NaN
# 418182     NaN       NaN  ...     NaN
# 418183     NaN       NaN  ...     NaN
#
#                                                     title volume  \
# 467     Sumerian Administrative and Legal Documents ca...    NaN
# 468                                                   NaN    NaN
# 469                                                   NaN    NaN
# 470                                                   NaN    NaN
# 471                                                   NaN    NaN
# ...                                                   ...    ...
# 418179                                                NaN    NaN
# 418180                                                NaN    NaN
# 418181                                                NaN    NaN
# 418182                                                NaN    NaN
# 418183                                                NaN    NaN
#
#         publication_history  series  oclc  accepted_by accepted  \
# 467                     NaN     NaN   NaN          820        1
# 468                     NaN     NaN   NaN          820        1
# 469                     NaN     NaN   NaN          820        1
# 470                     NaN     NaN   NaN          820        1
# 471                     NaN     NaN   NaN          820        1
# ...                     ...     ...   ...          ...      ...
# 418179                  NaN     NaN   NaN          820        1
# 418180                  NaN     NaN   NaN          820        1
# 418181                  NaN     NaN   NaN          820        1
# 418182                  NaN     NaN   NaN          820        1
# 418183                  NaN     NaN   NaN          820        1
#
#         designation_first designation_abbrev
# 467              CUSAS 35              CUSAS
# 468                 ATU 3                ATU
# 469                 ATU 3                ATU
# 470                 ATU 3                ATU
# 471                 ATU 3                ATU
# ...                   ...                ...
# 418179              RA 98                 RA
# 418180              RA 98                 RA
# 418181              RA 97                 RA
# 418182              RA 76                 RA
# 418183              RA 76                 RA
#
# [187926 rows x 31 columns]
